# %%
# %matplotlib notebook
# %config InlineBackend.figure_formats = {'svg',}
import pandas
import matplotlib.pyplot as plt
import numpy as np
import datetime
import matplotlib.dates as mdates

data=pandas.read_csv("query1.csv")
print(data)
# Out:
#       Unnamed: 0  Year  Month  Day  FlightsPerDay  CancFlightsPerDay  \
# 0              0  1994      1    1          12158                 64
# 1              1  1994      1    2          13579                 61
# 2              2  1994      1    3          14204                219
# 3              3  1994      1    4          14183               2207
# 4              4  1994      1    5          14122                673
# 5              5  1994      1    6          14049                761
# 6              6  1994      1    7          14072               1232
# 7              7  1994      1    8          12605               1206
# 8              8  1994      1    9          13228                147
# 9              9  1994      1   10          14122                261
# 10            10  1994      1   11          14121                194
# 11            11  1994      1   12          14166               1115
# 12            12  1994      1   13          14062                315
# ...

# %%
histD=[]
print(data[:1])
for x in data.itertuples():
    year= (getattr(x,"Year"))
    month= (getattr(x,"Month"))
    day= (getattr(x,"Day"))
    mydate = datetime.date(year,month, day)  #year, month, day   
    histD.append(mydate)
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
percentage = data['PercCancelled']
#print (histD)
legend = ['Percentage of cancelled flights per day']
plt.plot(histD, percentage, marker='|', linestyle='-', color='r', label='Square')
#plt.hist([1,2], color=['blue'])
plt.xlabel("Day")
plt.ylabel("Frequency")
plt.legend(legend)
plt.title('Percentage of cancelled flights  per day')
plt.savefig('test.png', bbox_inches='tight')
plt.show()
# Out:
#    Unnamed: 0  Year  Month  Day  FlightsPerDay  CancFlightsPerDay  \
# 0           0  1994      1    1          12158                 64
#
#    PercCancelled
# 0       0.005264
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import pickle

fig,ax = plt.subplots()
ax.plot([1,2,3],[10,-10,30])
pickle.dump(fig, open('FigureObject.fig.pickle', 'wb'))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pickle
figx = pickle.load(open('FigureObject.fig.pickle', 'rb'))

figx.show() # Show the figure, edit it, etc.!
# Out:
# <img src="data:image/png;base64,..." width="640">
